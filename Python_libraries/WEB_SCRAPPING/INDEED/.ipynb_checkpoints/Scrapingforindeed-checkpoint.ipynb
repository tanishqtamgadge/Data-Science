# %%
# installing the selenium
# !pip install selenium

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import selenium                        #automate webbrowser
from selenium import webdriver         #it will use browser from your machine
import time                            #halt your python programming

# %%
def get_url(position,location):
    position = position.replace(' ','+')
    location = location.replace(' ','+')
    template = 'https://in.indeed.com/jobs?q{}&l={}'
    url = template.format(position,location)
    return url

# %%
url = get_url('python','pune')
print(url)
# Out:
# https://in.indeed.com/jobs?qpython&l=pune

# %%
options = webdriver.ChromeOptions()
options.add_argument("--disable-blink-features=AutomationControlled")
driver = webdriver.Chrome(options=options)
driver.get(url)
time.sleep(3)

# %%
soup = BeautifulSoup(driver.page_source,'html.parser')

# %%
#fetching job cards
cards = soup.find_all('li','css-1ac2h1w eu4oa1w0')
print(len(cards))
# Out:
# 0

# %%
card = cards[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 card = cards[0]
#
# IndexError: list index out of range

# %%
  job_Name = card.find('a', {'class': 'jcs-JobTitle'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 job_Name = card.find('a', {'class': 'jcs-JobTitle'})
#
# NameError: name 'card' is not defined
